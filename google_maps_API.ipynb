# %%
#import libraries:
import time
import requests
import pandas as pd
import googlemaps 
import win32com.client
import random

# %%
API_Key = "AIzaSyDpy1uw8_RvkLGFEGEydm1Yon_1fMPIZhM"

#Run googlemaps key
map_client = googlemaps.Client(API_Key)

#Places we want to look for restaurants:

places = ["Lisbon", "Sintra", "Cascais", "Porto"]

#functions to get places:

def get_place_info(location_name):
    try:
        response = map_client.places(query=location_name)
        results = response.get("results")
        return results 

    except:
        print("could not find")
        return None

# %%
result_list = get_place_info(input("search for a place in Portugal: "))
# Out:
# search for a place in Portugal:  Ironhack

# %%
result_list
# Out:
# [{'business_status': 'OPERATIONAL',
#   'formatted_address': 'Heden Santa Apolonia Doca Jardim do Tabaco Terminal de Cruzeiros de Lisboa Edifício NE, 1º Piso, 1100-651 Lisboa, Portugal',
#   'geometry': {'location': {'lat': 38.7116745, 'lng': -9.1238244},
#    'viewport': {'northeast': {'lat': 38.71304632989272,
#      'lng': -9.12250987010728},
#     'southwest': {'lat': 38.71034667010728, 'lng': -9.125209529892723}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/school_pinlet',
#   'name': 'Ironhack Lisbon Tech Bootcamps',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 862,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114372901244204491122">A Google User</a>'],
#     'photo_reference': 'Aap_uEBIzCuBjTTfmrjB8WGTAYZ92ELLlDA6dQZKizQxnlwzGdP6okqnScRo0c7g-BVGwrI11xV7H-Xx1jdq0zLWp_4IaMf-HSac9cgjyfxFCVTffQ5Kb77oiG7DKybsOHd1BxaMCa5qq66vNWqfHR43h9v0vPZIOBa8k56Ui5z01m-7z-uB',
#     'width': 1536}],
#   'place_id': 'ChIJVai0wnk1GQ0R7GyY8b_gers',
#   'plus_code': {'compound_code': 'PV6G+MF Lisbon',
#    'global_code': '8CCGPV6G+MF'},
#   'rating': 4.9,
#   'reference': 'ChIJVai0wnk1GQ0R7GyY8b_gers',
#   'types': ['point_of_interest', 'establishment'],
#   'user_ratings_total': 28}]

# %%
def get_latlog(result_list):
    locations_data = []
    lat_log = []
    final_latlog = []
    for information in result_list[0].values():
        locations_data.append(information)
    
    for info_loc in locations_data[2].values():
        lat_log.append(info_loc)
        
    for lat_log_values in lat_log[0].values():
        final_latlog.append(lat_log_values)
    return final_latlog

lati_logi_info = get_latlog(result_list)

# %%
#Search near_by restaurants:

map_client = googlemaps.Client(API_Key)
lat_log = (lati_logi_info[0],lati_logi_info[1])
search_string = "restaurante"
distance = 750
business_list = []

response = map_client.places_nearby(
location = lat_log,
type = "restaurant",
radius = distance,
)

business_list.extend(response.get("results"))
next_page_token = response.get("next_page_token")

while next_page_token:
    time.sleep(random.random()+2)
    response = map_client.places_nearby(
        location = lat_log,
        type = "restaurant",
        radius = distance,
        page_token = next_page_token
    )
    business_list.extend(response.get("results"))
    next_page_token = response.get("next_page_token")

# %%
maps_df = pd.DataFrame(business_list)
maps_df["url"] = "https://google.com/maps/place/?q=place_id:" + maps_df["place_id"]

# %%
maps_df.shape
# Out:
# (60, 19)

# %%
# https://stackoverflow.com/questions/13070477/how-can-i-get-more-than-60-results-from-the-google-places-api   <-- info about retrieving more than 60 places
# https://hackernoon.com/how-i-sort-of-got-around-the-google-maps-api-results-limit-1c673e66ef36

# %%
maps_df
# Out:
#        business_status                                           geometry  \
# 0          OPERATIONAL  {'location': {'lat': 38.7130895, 'lng': -9.125...
# 1          OPERATIONAL  {'location': {'lat': 38.710891, 'lng': -9.1294...
# 2          OPERATIONAL  {'location': {'lat': 38.70972219999999, 'lng':...
# 3          OPERATIONAL  {'location': {'lat': 38.711381, 'lng': -9.1285...
# 4          OPERATIONAL  {'location': {'lat': 38.7097626, 'lng': -9.129...
# 5          OPERATIONAL  {'location': {'lat': 38.7140853, 'lng': -9.123...
# 6          OPERATIONAL  {'location': {'lat': 38.71079069999999, 'lng':...
# 7          OPERATIONAL  {'location': {'lat': 38.7117128, 'lng': -9.129...
# 8          OPERATIONAL  {'location': {'lat': 38.7111931, 'lng': -9.128...
# 9          OPERATIONAL  {'location': {'lat': 38.7118111, 'lng': -9.128...
# 10         OPERATIONAL  {'location': {'lat': 38.7127538, 'lng': -9.129...
# 11         OPERATIONAL  {'location': {'lat': 38.713564, 'lng': -9.1232...
# 12         OPERATIONAL  {'location': {'lat': 38.71281560000001, 'lng':...
# 13         OPERATIONAL  {'location': {'lat': 38.7130818, 'lng': -9.126...
# 14         OPERATIONAL  {'location': {'lat': 38.71272080000001, 'lng':...
# 15         OPERATIONAL  {'location': {'lat': 38.713623, 'lng': -9.1219...
# 16         OPERATIONAL  {'location': {'lat': 38.7142434, 'lng': -9.123...
# 17  CLOSED_TEMPORARILY  {'location': {'lat': 38.7126578, 'lng': -9.126...
# 18         OPERATIONAL  {'location': {'lat': 38.7116274, 'lng': -9.127...
# 19         OPERATIONAL  {'location': {'lat': 38.7111488, 'lng': -9.127...
# 20         OPERATIONAL  {'location': {'lat': 38.7117307, 'lng': -9.127...
# 21         OPERATIONAL  {'location': {'lat': 38.712606, 'lng': -9.1275...
# 22         OPERATIONAL  {'location': {'lat': 38.7121774, 'lng': -9.128...
# 23         OPERATIONAL  {'location': {'lat': 38.71093279999999, 'lng':...
# 24         OPERATIONAL  {'location': {'lat': 38.7104468, 'lng': -9.128...
# 25         OPERATIONAL  {'location': {'lat': 38.71088969999999, 'lng':...
# 26  CLOSED_TEMPORARILY  {'location': {'lat': 38.7138599, 'lng': -9.128...
# 27         OPERATIONAL  {'location': {'lat': 38.71039699999999, 'lng':...
# 28         OPERATIONAL  {'location': {'lat': 38.715698, 'lng': -9.1255...
# 29  CLOSED_TEMPORARILY  {'location': {'lat': 38.7156548, 'lng': -9.121...
# 30         OPERATIONAL  {'location': {'lat': 38.7160142, 'lng': -9.125...
# 31         OPERATIONAL  {'location': {'lat': 38.71053070000001, 'lng':...
# 32         OPERATIONAL  {'location': {'lat': 38.7091595, 'lng': -9.130...
# 33         OPERATIONAL  {'location': {'lat': 38.7102878, 'lng': -9.129...
# 34         OPERATIONAL  {'location': {'lat': 38.7115991, 'lng': -9.130...
# 35         OPERATIONAL  {'location': {'lat': 38.71104339999999, 'lng':...
# 36         OPERATIONAL  {'location': {'lat': 38.713851, 'lng': -9.1217...
# 37         OPERATIONAL  {'location': {'lat': 38.7093752, 'lng': -9.130...
# 38         OPERATIONAL  {'location': {'lat': 38.7117498, 'lng': -9.130...
# 39         OPERATIONAL  {'location': {'lat': 38.714401, 'lng': -9.1299...
# 40         OPERATIONAL  {'location': {'lat': 38.7145033, 'lng': -9.123...
# 41         OPERATIONAL  {'location': {'lat': 38.716901, 'lng': -9.1204...
# 42         OPERATIONAL  {'location': {'lat': 38.71416809999999, 'lng':...
# 43         OPERATIONAL  {'location': {'lat': 38.7111993, 'lng': -9.131...
# 44         OPERATIONAL  {'location': {'lat': 38.7096326, 'lng': -9.131...
# 45         OPERATIONAL  {'location': {'lat': 38.7127599, 'lng': -9.126...
# 46         OPERATIONAL  {'location': {'lat': 38.7109083, 'lng': -9.129...
# 47         OPERATIONAL  {'location': {'lat': 38.7142704, 'lng': -9.131...
# 48         OPERATIONAL  {'location': {'lat': 38.7136111, 'lng': -9.130...
# 49         OPERATIONAL  {'location': {'lat': 38.71154169999999, 'lng':...
# 50  CLOSED_TEMPORARILY  {'location': {'lat': 38.7119741, 'lng': -9.127...
# 51         OPERATIONAL  {'location': {'lat': 38.7102712, 'lng': -9.132...
# 52         OPERATIONAL  {'location': {'lat': 38.71194049999999, 'lng':...
# 53         OPERATIONAL  {'location': {'lat': 38.7112489, 'lng': -9.128...
# 54         OPERATIONAL  {'location': {'lat': 38.71198700000001, 'lng':...
# 55         OPERATIONAL  {'location': {'lat': 38.7134186, 'lng': -9.125...
# 56         OPERATIONAL  {'location': {'lat': 38.7112218, 'lng': -9.128...
# 57         OPERATIONAL  {'location': {'lat': 38.7124186, 'lng': -9.125...
# 58         OPERATIONAL  {'location': {'lat': 38.713613, 'lng': -9.1247...
# 59         OPERATIONAL  {'location': {'lat': 38.7111554, 'lng': -9.128...
#
#                                                  icon icon_background_color  \
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...               #909CE1
# 5   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 6   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 7   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 8   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 9   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 10  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 11  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 12  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 13  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 14  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 15  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 16  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 17  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 18  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 19  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 20  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 21  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 22  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 23  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 24  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 25  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 26  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 27  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 28  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 29  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 30  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 31  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 32  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 33  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 34  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 35  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 36  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 37  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 38  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 39  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 40  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 41  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 42  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 43  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 44  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 45  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 46  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 47  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 48  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 49  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 50  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 51  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 52  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 53  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 54  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 55  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 56  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 57  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 58  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 59  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
#
#                                    icon_mask_base_uri  \
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...
# 5   https://maps.gstatic.com/mapfiles/place_api/ic...
# 6   https://maps.gstatic.com/mapfiles/place_api/ic...
# 7   https://maps.gstatic.com/mapfiles/place_api/ic...
# 8   https://maps.gstatic.com/mapfiles/place_api/ic...
# 9   https://maps.gstatic.com/mapfiles/place_api/ic...
# 10  https://maps.gstatic.com/mapfiles/place_api/ic...
# 11  https://maps.gstatic.com/mapfiles/place_api/ic...
# 12  https://maps.gstatic.com/mapfiles/place_api/ic...
# 13  https://maps.gstatic.com/mapfiles/place_api/ic...
# 14  https://maps.gstatic.com/mapfiles/place_api/ic...
# 15  https://maps.gstatic.com/mapfiles/place_api/ic...
# 16  https://maps.gstatic.com/mapfiles/place_api/ic...
# 17  https://maps.gstatic.com/mapfiles/place_api/ic...
# 18  https://maps.gstatic.com/mapfiles/place_api/ic...
# 19  https://maps.gstatic.com/mapfiles/place_api/ic...
# 20  https://maps.gstatic.com/mapfiles/place_api/ic...
# 21  https://maps.gstatic.com/mapfiles/place_api/ic...
# 22  https://maps.gstatic.com/mapfiles/place_api/ic...
# 23  https://maps.gstatic.com/mapfiles/place_api/ic...
# 24  https://maps.gstatic.com/mapfiles/place_api/ic...
# 25  https://maps.gstatic.com/mapfiles/place_api/ic...
# 26  https://maps.gstatic.com/mapfiles/place_api/ic...
# 27  https://maps.gstatic.com/mapfiles/place_api/ic...
# 28  https://maps.gstatic.com/mapfiles/place_api/ic...
# 29  https://maps.gstatic.com/mapfiles/place_api/ic...
# 30  https://maps.gstatic.com/mapfiles/place_api/ic...
# 31  https://maps.gstatic.com/mapfiles/place_api/ic...
# 32  https://maps.gstatic.com/mapfiles/place_api/ic...
# 33  https://maps.gstatic.com/mapfiles/place_api/ic...
# 34  https://maps.gstatic.com/mapfiles/place_api/ic...
# 35  https://maps.gstatic.com/mapfiles/place_api/ic...
# 36  https://maps.gstatic.com/mapfiles/place_api/ic...
# 37  https://maps.gstatic.com/mapfiles/place_api/ic...
# 38  https://maps.gstatic.com/mapfiles/place_api/ic...
# 39  https://maps.gstatic.com/mapfiles/place_api/ic...
# 40  https://maps.gstatic.com/mapfiles/place_api/ic...
# 41  https://maps.gstatic.com/mapfiles/place_api/ic...
# 42  https://maps.gstatic.com/mapfiles/place_api/ic...
# 43  https://maps.gstatic.com/mapfiles/place_api/ic...
# 44  https://maps.gstatic.com/mapfiles/place_api/ic...
# 45  https://maps.gstatic.com/mapfiles/place_api/ic...
# 46  https://maps.gstatic.com/mapfiles/place_api/ic...
# 47  https://maps.gstatic.com/mapfiles/place_api/ic...
# 48  https://maps.gstatic.com/mapfiles/place_api/ic...
# 49  https://maps.gstatic.com/mapfiles/place_api/ic...
# 50  https://maps.gstatic.com/mapfiles/place_api/ic...
# 51  https://maps.gstatic.com/mapfiles/place_api/ic...
# 52  https://maps.gstatic.com/mapfiles/place_api/ic...
# 53  https://maps.gstatic.com/mapfiles/place_api/ic...
# 54  https://maps.gstatic.com/mapfiles/place_api/ic...
# 55  https://maps.gstatic.com/mapfiles/place_api/ic...
# 56  https://maps.gstatic.com/mapfiles/place_api/ic...
# 57  https://maps.gstatic.com/mapfiles/place_api/ic...
# 58  https://maps.gstatic.com/mapfiles/place_api/ic...
# 59  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                                  name        opening_hours  \
# 0                                            Sr. Fado  {'open_now': False}
# 1                             Santo António de Alfama                  NaN
# 2                   Clube de Fado - Fado & Food Group  {'open_now': False}
# 3                                            Lautasco  {'open_now': False}
# 4                          Palacete Chafariz d'El Rei   {'open_now': True}
# 5                                          Faz Figura  {'open_now': False}
# 6                                 São Miguel d'Alfama   {'open_now': True}
# 7                            Restaurent Castelo Pição   {'open_now': True}
# 8                                      Flor dos Arcos   {'open_now': True}
# 9                                        Alfama Grill   {'open_now': True}
# 10                                     Charlot Alfama   {'open_now': True}
# 11                           Telepizza Santa Apolónia   {'open_now': True}
# 12                                      Alfama Cellar  {'open_now': False}
# 13                                     Mesa De Frades  {'open_now': False}
# 14                                     wine & burguer                  NaN
# 15                                      Cais da Pedra   {'open_now': True}
# 16                                         Maçã Verde  {'open_now': False}
# 17                                       Porto Alfama                  NaN
# 18                      A Muralha Tasca Típica Lisboa   {'open_now': True}
# 19                 A Travessa do Fado (Museu do Fado)   {'open_now': True}
# 20                                           Pateo 13  {'open_now': False}
# 21                            doVigário PubandRecords  {'open_now': False}
# 22                                         Fado Maior                  NaN
# 23                                  Coração de Alfama  {'open_now': False}
# 24                                      Fama d'Alfama  {'open_now': False}
# 25                       São Miguel Grandes Cantorias   {'open_now': True}
# 26            Fama d'Alfama Charcutaria | Restaurante                  NaN
# 27              Vamos ao Algarve - Bar & Shop Gourmet  {'open_now': False}
# 28                          Santa Clara dos Cogumelos  {'open_now': False}
# 29                             Arts Cafe, Event Venue                  NaN
# 30                                   Focaccia in Giro  {'open_now': False}
# 31                                   Medrosa d'Alfama   {'open_now': True}
# 32                            Casa de Linhares - FADO  {'open_now': False}
# 33                         Fado em Si - Casa de Fados  {'open_now': False}
# 34                           Miradouro de Santa Luzia   {'open_now': True}
# 35                                     Pastel do Fado   {'open_now': True}
# 36                                           Casanova   {'open_now': True}
# 37                                             Maruto  {'open_now': False}
# 38                               Farol de Santa Luzia  {'open_now': False}
# 39      Restaurante ,O Cantinho n.10 - de sta Marinha   {'open_now': True}
# 40                           A Parreirinha do Paraíso   {'open_now': True}
# 41                                             Zeluna   {'open_now': True}
# 42                                Princesa do Castelo  {'open_now': False}
# 43                                           Audrey´s   {'open_now': True}
# 44                                          Fado CLUB                  NaN
# 45                                              Tolan   {'open_now': True}
# 46                                           A Baiuca  {'open_now': False}
# 47                                            O Prego   {'open_now': True}
# 48                           Frei Papinhas Restaurant   {'open_now': True}
# 49  Parreirinha de Alfama - FADO & TRADIÇÃO desde ...  {'open_now': False}
# 50  Primo Basílico Pizza al taglio e delizie Italiane                  NaN
# 51                                          Rio Coura   {'open_now': True}
# 52                                Guitarras de Lisboa  {'open_now': False}
# 53                                Salgado Esteves Lda                  NaN
# 54                           Petisqueira Conqvistador   {'open_now': True}
# 55                               Pastelaria Alfacinha   {'open_now': True}
# 56                                   Taverna D'El Rey  {'open_now': False}
# 57                                           Sardinha   {'open_now': True}
# 58                                        Arcaz Velho   {'open_now': True}
# 59                                 Barracão de Alfama  {'open_now': False}
#
#                                                photos  \
# 0   [{'height': 3000, 'html_attributions': ['<a hr...
# 1   [{'height': 4032, 'html_attributions': ['<a hr...
# 2   [{'height': 5247, 'html_attributions': ['<a hr...
# 3   [{'height': 4312, 'html_attributions': ['<a hr...
# 4   [{'height': 810, 'html_attributions': ['<a hre...
# 5   [{'height': 3843, 'html_attributions': ['<a hr...
# 6   [{'height': 480, 'html_attributions': ['<a hre...
# 7   [{'height': 1960, 'html_attributions': ['<a hr...
# 8   [{'height': 1767, 'html_attributions': ['<a hr...
# 9   [{'height': 3024, 'html_attributions': ['<a hr...
# 10  [{'height': 3120, 'html_attributions': ['<a hr...
# 11                                                NaN
# 12  [{'height': 4032, 'html_attributions': ['<a hr...
# 13  [{'height': 2448, 'html_attributions': ['<a hr...
# 14                                                NaN
# 15  [{'height': 3000, 'html_attributions': ['<a hr...
# 16  [{'height': 3024, 'html_attributions': ['<a hr...
# 17  [{'height': 757, 'html_attributions': ['<a hre...
# 18  [{'height': 2000, 'html_attributions': ['<a hr...
# 19  [{'height': 3024, 'html_attributions': ['<a hr...
# 20  [{'height': 3024, 'html_attributions': ['<a hr...
# 21  [{'height': 2816, 'html_attributions': ['<a hr...
# 22  [{'height': 1536, 'html_attributions': ['<a hr...
# 23  [{'height': 4032, 'html_attributions': ['<a hr...
# 24  [{'height': 1332, 'html_attributions': ['<a hr...
# 25  [{'height': 810, 'html_attributions': ['<a hre...
# 26  [{'height': 1840, 'html_attributions': ['<a hr...
# 27  [{'height': 2268, 'html_attributions': ['<a hr...
# 28  [{'height': 3024, 'html_attributions': ['<a hr...
# 29  [{'height': 1365, 'html_attributions': ['<a hr...
# 30  [{'height': 946, 'html_attributions': ['<a hre...
# 31  [{'height': 1080, 'html_attributions': ['<a hr...
# 32  [{'height': 1036, 'html_attributions': ['<a hr...
# 9   {'compound_code': 'PV6C+PM Lisbon, Portugal', ...          2.0     3.4
# 10  {'compound_code': 'PV7C+49 Lisbon, Portugal', ...          NaN     4.6
# 11  {'compound_code': 'PV7G+CP Lisbon, Portugal', ...          NaN     1.0
# 12  {'compound_code': 'PV7F+4H Lisbon, Portugal', ...          2.0     4.5
# 13  {'compound_code': 'PV7F+6H Lisbon, Portugal', ...          NaN     4.4
# 14  {'compound_code': 'PV7F+3C Lisbon, Portugal', ...          NaN     2.0
# 15  {'compound_code': 'PV7H+C6 Lisbon, Portugal', ...          2.0     4.1
# 16  {'compound_code': 'PV7G+MQ Lisbon, Portugal', ...          1.0     4.5
# 17  {'compound_code': 'PV7F+36 Lisbon, Portugal', ...          NaN     4.5
# 18  {'compound_code': 'PV6F+M3 Lisbon, Portugal', ...          1.0     4.4
# 19  {'compound_code': 'PV6C+FW Lisbon, Portugal', ...          2.0     4.2
# 20  {'compound_code': 'PV6C+MV Lisbon, Portugal', ...          NaN     4.3
# 21  {'compound_code': 'PV7C+2X Lisbon, Portugal', ...          1.0     4.8
# 22  {'compound_code': 'PV6C+VF Lisbon, Portugal', ...          NaN     3.6
# 23  {'compound_code': 'PV6C+9C Lisbon, Portugal', ...          NaN     4.1
# 24  {'compound_code': 'PV6C+5C Lisbon, Portugal', ...          2.0     4.3
# 25  {'compound_code': 'PV6C+99 Lisbon, Portugal', ...          2.0     2.9
# 26  {'compound_code': 'PV7C+GJ Lisbon, Portugal', ...          NaN     4.4
# 27  {'compound_code': 'PV6C+59 Lisbon, Portugal', ...          NaN     4.1
# 28  {'compound_code': 'PV8F+7Q Lisbon, Portugal', ...          2.0     4.7
# 29  {'compound_code': 'PV8H+77 Lisbon, Portugal', ...          1.0     4.4
# 30  {'compound_code': 'PV8F+CW Lisbon, Portugal', ...          1.0     4.6
# 31  {'compound_code': 'PV6C+66 Lisbon, Portugal', ...          2.0     4.3
# 32  {'compound_code': 'PV59+MJ Lisbon, Portugal', ...          2.0     4.4
# 33  {'compound_code': 'PV6C+43 Lisbon, Portugal', ...          3.0     4.0
# 34  {'compound_code': 'PV69+JV Lisbon, Portugal', ...          2.0     4.6
# 35  {'compound_code': 'PV69+CR Lisbon, Portugal', ...          NaN     3.6
# 36  {'compound_code': 'PV7H+G7 Lisbon, Portugal', ...          2.0     4.5
# 37  {'compound_code': 'PV59+QX Lisbon, Portugal', ...          2.0     4.6
# 38  {'compound_code': 'PV69+MQ Lisbon, Portugal', ...          2.0     4.5
# 39  {'compound_code': 'PV7C+Q2 Lisbon, Portugal', ...          1.0     3.8
# 40  {'compound_code': 'PV7G+RF Lisbon, Portugal', ...          1.0     4.6
# 41  {'compound_code': 'PV8H+QR Lisbon, Portugal', ...          1.0     4.4
# 42  {'compound_code': 'PV79+MP Lisbon, Portugal', ...          2.0     4.4
# 43  {'compound_code': 'PV69+FF Lisbon, Portugal', ...          2.0     4.4
# 44  {'compound_code': 'PV59+VH Lisbon, Portugal', ...          NaN     3.4
# 45  {'compound_code': 'PV7F+4H Lisbon, Portugal', ...          1.0     2.9
# 46  {'compound_code': 'PV6C+98 Lisbon, Portugal', ...          NaN     4.2
# 47  {'compound_code': 'PV79+PH Lisbon, Portugal', ...          2.0     4.1
# 48  {'compound_code': 'PV79+CQ Lisbon, Portugal', ...          2.0     3.3
# 49  {'compound_code': 'PV6C+JQ Lisbon, Portugal', ...          3.0     4.4
# 50  {'compound_code': 'PV6F+Q3 Lisbon, Portugal', ...          1.0     4.6
# 51  {'compound_code': 'PV69+45 Lisbon, Portugal', ...          1.0     4.2
# 52  {'compound_code': 'PV6F+Q6 Lisbon, Portugal', ...          2.0     4.3
# 53  {'compound_code': 'PV6C+FH Lisbon, Portugal', ...          NaN     4.3
# 54  {'compound_code': 'PV69+Q3 Lisbon, Portugal', ...          2.0     4.4
# 55  {'compound_code': 'PV7F+9V Lisbon, Portugal', ...          1.0     4.1
# 56  {'compound_code': 'PV6C+FJ Lisbon, Portugal', ...          4.0     2.8
# 57  {'compound_code': 'PV6F+XP Lisbon, Portugal', ...          1.0     4.5
# 58  {'compound_code': 'PV7G+C3 Lisbon, Portugal', ...          2.0     4.0
# 59  {'compound_code': 'PV6C+FG Lisbon, Portugal', ...          2.0     4.2
#
#                       reference   scope  \
# 0   ChIJ6RnQDHU0GQ0RXgZT0UTwlNc  GOOGLE
# 1   ChIJdQ2UnHY0GQ0RKdaT0O6lB1o  GOOGLE
# 2   ChIJV-jS2nY0GQ0Rl2LL675xCYE  GOOGLE
# 3   ChIJOzB2LnQ0GQ0RJPE7z_jjpQE  GOOGLE
# 4   ChIJ_YfHpXY0GQ0RAPlfcB5-cKM  GOOGLE
# 5   ChIJ1227UHU0GQ0RT8Xkw5_l7tM  GOOGLE
# 6   ChIJ6VuTnHY0GQ0RUo_gETPDtLw  GOOGLE
# 7   ChIJD92QqIg1GQ0RxvITI-I_DUg  GOOGLE
# 8   ChIJ555xMXQ0GQ0R_Jw8tqTIo64  GOOGLE
# 9   ChIJUZx70XU0GQ0Rz1MT17wAPmA  GOOGLE
# 10  ChIJ8RRqdXY0GQ0RiEYrO9FxQy4  GOOGLE
# 11  ChIJd3cVtAo0GQ0ReDz5HYxxfGw  GOOGLE
# 12  ChIJIysipnU0GQ0R9UWeeoMm6AM  GOOGLE
# 13  ChIJDa06CnU0GQ0Rd6J6YEcLLgw  GOOGLE
# 14  ChIJaarPoHU0GQ0RlZJfq35NAyM  GOOGLE
# 15  ChIJLT6wlQo0GQ0Ruk2kDcEw1fE  GOOGLE
# 16  ChIJ98-irgo0GQ0RjcBnypTTSII  GOOGLE
# 17  ChIJkcMs7YczGQ0RhuBWWCg-Csg  GOOGLE
# 18  ChIJY2lhS3Q0GQ0RreM8oxobAfU  GOOGLE
# 19  ChIJeZYlNnQ0GQ0RyOYAEhy0fy8  GOOGLE
# 20  ChIJr8pBzIkzGQ0RBBncMSSlsFE  GOOGLE
# 21  ChIJ4WGsuHU0GQ0RrRat8QNLx40  GOOGLE
# 22  ChIJf0gt2HU0GQ0RV3dEJe7J2sA  GOOGLE
# 23  ChIJY5jiJ3Q0GQ0Ru30jC0gTklM  GOOGLE
GOOGLE
#
#                                                 types  user_ratings_total  \
# 0   [restaurant, food, point_of_interest, establis...                 420
# 1   [restaurant, food, point_of_interest, establis...                 514
# 2   [restaurant, food, point_of_interest, establis...                1174
# 3   [restaurant, food, point_of_interest, establis...                 550
# 4   [cafe, lodging, restaurant, food, point_of_int...                 160
# 5   [bar, restaurant, food, point_of_interest, est...                 578
# 6   [restaurant, food, point_of_interest, establis...                 447
# 7   [restaurant, food, point_of_interest, establis...                   6
# 8   [restaurant, food, point_of_interest, establis...                 261
# 9   [bar, liquor_store, restaurant, food, point_of...                 567
# 10  [cafe, bar, restaurant, food, point_of_interes...                  51
# 11  [restaurant, food, point_of_interest, establis...                   2
# 12  [restaurant, food, point_of_interest, establis...                 690
# 13  [restaurant, food, point_of_interest, establis...                 400
# 14  [restaurant, food, point_of_interest, establis...                   1
# 15  [restaurant, food, point_of_interest, establis...                 801
# 16  [restaurant, food, point_of_interest, establis...                 651
# 17  [restaurant, bar, food, point_of_interest, est...                 151
# 18  [restaurant, food, point_of_interest, establis...                 799
# 19  [restaurant, food, point_of_interest, establis...                 207
# 20  [restaurant, food, point_of_interest, establis...                 767
# 21  [electronics_store, home_goods_store, bar, res...                 291
# 22  [restaurant, food, point_of_interest, establis...                  34
# 23  [restaurant, food, point_of_interest, establis...                 367
# 24  [restaurant, food, point_of_interest, establis...                 348
# 25  [restaurant, food, point_of_interest, establis...                 159
# 26  [restaurant, food, point_of_interest, establis...                 117
# 27  [restaurant, bar, food, point_of_interest, est...                 129
# 28  [restaurant, food, point_of_interest, establis...                 633
# 29  [restaurant, food, point_of_interest, establis...                 106
# 30  [restaurant, food, point_of_interest, establis...                 277
# 31  [bar, restaurant, food, point_of_interest, est...                 470
# 32  [restaurant, food, point_of_interest, establis...                 585
# 33  [restaurant, food, point_of_interest, establis...                 253
# 34  [restaurant, tourist_attraction, food, point_o...               18692
# 35  [restaurant, food, point_of_interest, establis...                 431
# 36  [restaurant, food, point_of_interest, establis...                2900
# 37  [restaurant, food, point_of_interest, establis...                 508
# 38  [restaurant, food, point_of_interest, establis...                 543
# 39  [restaurant, food, point_of_interest, establis...                 145
# 40  [restaurant, food, point_of_interest, establis...                 493
# 41  [restaurant, food, point_of_interest, establis...                 417
# 42  [restaurant, food, point_of_interest, establis...                 502
# 43  [restaurant, cafe, bar, food, point_of_interes...                 541
# 44  [restaurant, food, point_of_interest, establis...                   5
# 45  [restaurant, bar, liquor_store, food, point_of...                 135
# 46  [restaurant, food, point_of_interest, establis...                 481
# 47  [restaurant, food, point_of_interest, establis...                 839
# 48  [restaurant, food, point_of_interest, establis...                 221
# 49  [restaurant, food, point_of_interest, establis...                 584
# 50  [restaurant, food, point_of_interest, establis...                 458
# 51  [restaurant, food, point_of_interest, establis...                 679
# 52  [restaurant, food, point_of_interest, establis...                 227
# 53  [restaurant, food, point_of_interest, establis...                   9
# 54  [bar, restaurant, food, point_of_interest, est...                 792
# 55  [cafe, bakery, bar, liquor_store, restaurant, ...                 104
# 56  [restaurant, food, point_of_interest, establis...                 583
# 57  [restaurant, food, point_of_interest, establis...                 307
# 58  [bar, restaurant, food, point_of_interest, est...                 403
# 59  [restaurant, food, point_of_interest, establis...                 405
#
#                                              vicinity permanently_closed  \
# 0                                Rua dos Remédios 176                NaN
# 1                           Beco São Miguel 7, Lisboa                NaN
# 49  https://google.com/maps/place/?q=place_id:ChIJ...
# 50  https://google.com/maps/place/?q=place_id:ChIJ...
# 51  https://google.com/maps/place/?q=place_id:ChIJ...
# 52  https://google.com/maps/place/?q=place_id:ChIJ...
# 53  https://google.com/maps/place/?q=place_id:ChIJ...
# 54  https://google.com/maps/place/?q=place_id:ChIJ...
# 55  https://google.com/maps/place/?q=place_id:ChIJ...
# 56  https://google.com/maps/place/?q=place_id:ChIJ...
# 57  https://google.com/maps/place/?q=place_id:ChIJ...
# 58  https://google.com/maps/place/?q=place_id:ChIJ...
# 59  https://google.com/maps/place/?q=place_id:ChIJ...

# %%
#import libraries:
import time
import pandas as pd
import googlemaps 
import random

#My API_Key:
API_Key = "AIzaSyDpy1uw8_RvkLGFEGEydm1Yon_1fMPIZhM"

#Running googlemaps key:
map_client = googlemaps.Client(API_Key)

#Function to get places:
def get_place_info(location_name):
    try:
        response = map_client.places(query=location_name)
        results = response.get("results")
        return results 

    except:
        print("could not find")
        return None
 
#Ask the user to input a place address or city, searching the input on the get_place_info function:
result_list = get_place_info(input("search for a place/address/city in Portugal: "))


#Function to get the longitude and latitude of the place we chose in result_list:    
def get_latlog(result_list):
    locations_data = []
    lat_log = []
    final_latlog = []
    for information in result_list[0].values():
        locations_data.append(information)
    
    for info_loc in locations_data[2].values():
        lat_log.append(info_loc)
        
    for lat_log_values in lat_log[0].values():
        final_latlog.append(lat_log_values)
    return final_latlog

lati_logi_info = get_latlog(result_list)


"""Next we will Search for restaurants that are in a X meter distance 
from the place we chose, by getting the latitude and longitude from
get_latlog function: """

def restaurants_nearby(lati_logi_info):
    map_client = googlemaps.Client(API_Key)
    lat_log = (lati_logi_info[0],lati_logi_info[1])
#    search_string = input("what kind of food would you like to eat there?")
    distance = input("What is your radius distance in meters?")
    while int(distance) > 2000:
            display("Ohh, don't walk that much, choose a distance inferior of 2000 m")
            distance = input("What is your radius distance in meters?")   
    business_list = []

    response = map_client.places_nearby(
    location = lat_log,
#    keyword = search_string,
    type = "restaurant",
    radius = distance,
    )

    business_list.extend(response.get("results"))
    next_page_token = response.get("next_page_token")

    while next_page_token:
        time.sleep(random.random()+2)
        response = map_client.places_nearby(
        location = lat_log,
#        keyword = search_string,
        type = "restaurant",
        radius = distance,
        page_token = next_page_token
    )
        business_list.extend(response.get("results"))
        next_page_token = response.get("next_page_token")
    
    return business_list

#Display maps_df table:
maps_df = pd.DataFrame(restaurants_nearby(lati_logi_info))
maps_df["url"] = "https://google.com/maps/place/?q=place_id:" + maps_df["place_id"]
display(maps_df.head(10))
# Out:
# search for a place/address/city in Portugal:  terreiro do paço
# What is your radius distance in meters? 1000
#       business_status                                           geometry  \
# 0         OPERATIONAL  {'location': {'lat': 38.7130556, 'lng': -9.139...
# 1         OPERATIONAL  {'location': {'lat': 38.7115028, 'lng': -9.138...
# 2         OPERATIONAL  {'location': {'lat': 38.70972219999999, 'lng':...
# 3         OPERATIONAL  {'location': {'lat': 38.71009939999999, 'lng':...
# 4  CLOSED_TEMPORARILY  {'location': {'lat': 38.7124655, 'lng': -9.142...
# 5         OPERATIONAL  {'location': {'lat': 38.709134, 'lng': -9.1333...
# 6         OPERATIONAL  {'location': {'lat': 38.7086706, 'lng': -9.135...
# 7         OPERATIONAL  {'location': {'lat': 38.710891, 'lng': -9.1294...
# 8         OPERATIONAL  {'location': {'lat': 38.7115083, 'lng': -9.140...
# 9         OPERATIONAL  {'location': {'lat': 38.7097626, 'lng': -9.129...
#
#                                                 icon icon_background_color  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...               #909CE1
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...               #909CE1
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 5  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 6  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 7  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 8  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 9  https://maps.gstatic.com/mapfiles/place_api/ic...               #909CE1
#
#                                   icon_mask_base_uri  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...
# 5  https://maps.gstatic.com/mapfiles/place_api/ic...
# 6  https://maps.gstatic.com/mapfiles/place_api/ic...
# 7  https://maps.gstatic.com/mapfiles/place_api/ic...
# 8  https://maps.gstatic.com/mapfiles/place_api/ic...
# 9  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                 name        opening_hours  \
# 0                 The Art Inn Lisbon   {'open_now': True}
# 1              Brown's Central Hotel   {'open_now': True}
# 2  Clube de Fado - Fado & Food Group  {'open_now': False}
# 3                           Belcanto  {'open_now': False}
# 4                Cervejaria Trindade                  NaN
# 5                    Taberna Moderna  {'open_now': False}
# 6                 Martinho da Arcada   {'open_now': True}
# 7            Santo António de Alfama                  NaN
# 8               Sacramento do Chiado  {'open_now': False}
# 9         Palacete Chafariz d'El Rei   {'open_now': True}
#
#                                               photos  \
# 0  [{'height': 2268, 'html_attributions': ['<a hr...
# 1  [{'height': 3264, 'html_attributions': ['<a hr...
# 2  [{'height': 5247, 'html_attributions': ['<a hr...
# 3  [{'height': 608, 'html_attributions': ['<a hre...
# 4  [{'height': 1367, 'html_attributions': ['<a hr...
# 5  [{'height': 998, 'html_attributions': ['<a hre...
# 6  [{'height': 3024, 'html_attributions': ['<a hr...
# 7  [{'height': 4032, 'html_attributions': ['<a hr...
# 8  [{'height': 3456, 'html_attributions': ['<a hr...
# 9  [{'height': 810, 'html_attributions': ['<a hre...
#
#                       place_id  \
# 0  ChIJITS6qng0GQ0RYMBD2MNlQwE
# 1  ChIJiULG6Hg0GQ0REhiOp3X8fYA
# 2  ChIJV-jS2nY0GQ0Rl2LL675xCYE
# 3  ChIJITj75340GQ0RXULVgWMFloA
# 4  ChIJbymNeX80GQ0ROXnZMyq-WxM
# 5  ChIJ8USpSXc0GQ0RAIMnuSbwXp8
# 6  ChIJIcori3k0GQ0RquwgxxH1IN0
# 7  ChIJdQ2UnHY0GQ0RKdaT0O6lB1o
# 8  ChIJYaS4M380GQ0REdyJPFfvokc
# 9  ChIJ_YfHpXY0GQ0RAPlfcB5-cKM
#
#                                            plus_code  rating  \
# 0  {'compound_code': 'PV76+62 Lisbon, Portugal', ...     4.3
# 1  {'compound_code': 'PV66+JM Lisbon, Portugal', ...     4.5
# 2  {'compound_code': 'PV59+VH Lisbon, Portugal', ...     4.2
# 3  {'compound_code': 'PV65+2C Lisbon, Portugal', ...     4.6
# 4  {'compound_code': 'PV65+X2 Lisbon, Portugal', ...     4.1
# 5  {'compound_code': 'PV58+MM Lisbon, Portugal', ...     4.4
# 6  {'compound_code': 'PV57+FM Lisbon, Portugal', ...     4.2
# 7  {'compound_code': 'PV6C+96 Lisbon, Portugal', ...     4.0
# 8  {'compound_code': 'PV65+JV Lisbon, Portugal', ...     4.4
# 9  {'compound_code': 'PV5C+W5 Lisbon, Portugal', ...     4.6
#
#                      reference   scope  \
# 0  ChIJITS6qng0GQ0RYMBD2MNlQwE  GOOGLE
# 1  ChIJiULG6Hg0GQ0REhiOp3X8fYA  GOOGLE
# 2  ChIJV-jS2nY0GQ0Rl2LL675xCYE  GOOGLE
# 3  ChIJITj75340GQ0RXULVgWMFloA  GOOGLE
# 4  ChIJbymNeX80GQ0ROXnZMyq-WxM  GOOGLE
# 5  ChIJ8USpSXc0GQ0RAIMnuSbwXp8  GOOGLE
# 6  ChIJIcori3k0GQ0RquwgxxH1IN0  GOOGLE
# 7  ChIJdQ2UnHY0GQ0RKdaT0O6lB1o  GOOGLE
# 8  ChIJYaS4M380GQ0REdyJPFfvokc  GOOGLE
# 9  ChIJ_YfHpXY0GQ0RAPlfcB5-cKM  GOOGLE
#
#                                                types  user_ratings_total  \
# 0  [cafe, lodging, bar, restaurant, food, point_o...                 176
# 1  [lodging, bar, restaurant, food, point_of_inte...                 827
# 2  [restaurant, food, point_of_interest, establis...                1174
# 3  [restaurant, food, point_of_interest, establis...                 857
# 4  [restaurant, bar, food, point_of_interest, est...                4726
# 5  [bar, restaurant, food, point_of_interest, est...                 825
# 6  [tourist_attraction, restaurant, food, point_o...                1174
# 7  [restaurant, food, point_of_interest, establis...                 514
# 8  [restaurant, cafe, bar, food, point_of_interes...                1577
# 9  [cafe, lodging, restaurant, food, point_of_int...                 160
#
#                                    vicinity  price_level permanently_closed  \
# 0             Rua 1º de Dezembro 31, Lisboa          NaN                NaN
# 1            Rua dos Sapateiros 144, Lisboa          NaN                NaN
# 2       Rua de São João da Praça 86, Lisboa          3.0                NaN
# 3               Rua Serpa Pinto 10A, Lisboa          4.0                NaN
# 4         Rua Nova da Trindade 20 C, Lisboa          2.0               True
# 5          Rua dos Bacalhoeiros 18A, Lisboa          2.0                NaN
# 6               Praça do Comércio 3, Lisboa          2.0                NaN
# 7                 Beco São Miguel 7, Lisboa          2.0                NaN
# 8     Calçada do Sacramento 40 a 46, Lisboa          2.0                NaN
# 9  Travessa do Chafariz de El-Rei 6, Lisboa          NaN                NaN
#
#                                                  url
# 0  https://google.com/maps/place/?q=place_id:ChIJ...
# 1  https://google.com/maps/place/?q=place_id:ChIJ...
# 2  https://google.com/maps/place/?q=place_id:ChIJ...
# 3  https://google.com/maps/place/?q=place_id:ChIJ...
# 4  https://google.com/maps/place/?q=place_id:ChIJ...
# 5  https://google.com/maps/place/?q=place_id:ChIJ...
# 6  https://google.com/maps/place/?q=place_id:ChIJ...
# 7  https://google.com/maps/place/?q=place_id:ChIJ...
# 8  https://google.com/maps/place/?q=place_id:ChIJ...
# 9  https://google.com/maps/place/?q=place_id:ChIJ...

# %%
maps_df.to_csv(r"C:\Users\crocs\OneDrive - Universidade de Lisboa\Ambiente de Trabalho\Gonçalo\College&Courses\Data Analytics- IronHack\Course Data Analytics\Projects\Project3\Project3\google_maps.csv")
